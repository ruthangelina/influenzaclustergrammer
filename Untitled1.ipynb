# %%
pip install --upgrade clustergrammer_widget
# Out:
# Requirement already up-to-date: clustergrammer_widget in ./anaconda3/lib/python3.7/site-packages (1.13.3)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
#   File "<ipython-input-2-e3a674b8a334>", line 1
#     jupyter nbextension enable --py --sys-prefix widgetsnbextension
#                       ^
# SyntaxError: invalid syntax

# %%
from clustergrammer_widget import *

# %%
net = Network(clustergrammer_widget)

# %%
# load matrix file
net.load_file('Desktop/biojupie_expression.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-d2257a6feb82> in <module>
#       1 # load matrix file
# ----> 2 net.load_file('Desktop/biojupie_expression.txt')
#       3
#
# ~/anaconda3/lib/python3.7/site-packages/clustergrammer_widget/clustergrammer/__init__.py in load_file(self, filename)
#      45     Load TSV file.
#      46     '''
# ---> 47     load_data.load_file(self, filename)
#      48
#      49   def load_file_as_string(self, file_string, filename=''):
#
# ~/anaconda3/lib/python3.7/site-packages/clustergrammer_widget/clustergrammer/load_data.py in load_file(net, filename)
#      20   net.reset()
#      21
# ---> 22   f = open(filename, 'r')
#      23
#      24   file_string = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop/biojupie_expression.txt'

# %%
# cluster using default parameters
net.cluster(enrichrgram=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-8221b7db68e6> in <module>
#       1 # cluster using default parameters
# ----> 2 net.cluster(enrichrgram=True)
#
# ~/anaconda3/lib/python3.7/site-packages/clustergrammer_widget/clustergrammer/__init__.py in cluster(self, dist_type, run_clustering, dendro, views, linkage_type, sim_mat, filter_sim, calc_cat_pval, run_enrichr, enrichrgram)
#      97                                    calc_cat_pval=calc_cat_pval,
#      98                                    run_enrichr=run_enrichr,
# ---> 99                                    enrichrgram=enrichrgram)
#     100
#     101   def make_clust(self, dist_type='cosine', run_clustering=True,
#
# ...

# %%
from nbextensions import *

# %%
pip install nbextension
# Out:
# ...
#   Could not find a version that satisfies the requirement nbextension (from versions: )
# No matching distribution found for nbextension
# Note: you may need to restart the kernel to use updated packages.

# %%
net.widget()
# Out:
# clustergrammer_widget(network='{"row_nodes": [], "col_nodes": [], "links": [], "mat": [], "cat_colors": {"row"…

# %%
# import the widget
from clustergrammer_widget import *
from copy import deepcopy

# load data into new network instance and cluster
net = deepcopy(Network())
net.load_file('Desktop/biojupie_expression.txt')
net.make_clust()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-b033260b1ebc> in <module>
#       5 # load data into new network instance and cluster
#       6 net = deepcopy(Network())
# ----> 7 net.load_file('Desktop/biojupie_expression.txt')
#       8 net.make_clust()
#       9
#
# ~/anaconda3/lib/python3.7/site-packages/clustergrammer_widget/clustergrammer/__init__.py in load_file(self, filename)
#      45     Load TSV file.
#      46     '''
# ---> 47     load_data.load_file(self, filename)
#      48
#      49   def load_file_as_string(self, file_string, filename=''):
#
# ~/anaconda3/lib/python3.7/site-packages/clustergrammer_widget/clustergrammer/load_data.py in load_file(net, filename)
#      20   net.reset()
#      21
# ---> 22   f = open(filename, 'r')
#      23
#      24   file_string = f.read()
#
# ...

# %%
#net= Network(clustergrammer_widget)
net.load_file ('Desktop/biojupie_expression.txt')
net.cluster (enrichrgram=True)
net.widget()

# %%
import ipywidgets as widgets
from IPython.display import display
w = widgets.IntSlider()
display(w)

# %%
net.viz

# %%
w=net.widget()
display(w)

# %%
Network(clustergrammer_widget)

# %%
import numpy as np
import pandas as pd

# generate random matrix
num_rows = 500
num_cols = 10
np.random.seed(seed=100)
mat = np.random.rand(num_rows, num_cols)

# make row and col labels
rows = range(num_rows)
cols = range(num_cols)
rows = [str(i) for i in rows]
cols = [str(i) for i in cols]

# make dataframe 
df = pd.DataFrame(data=mat, columns=cols, index=rows)

# %%
mat=
# Out:
#   File "<ipython-input-12-6394d7c77d71>", line 1
#     mat=
#          ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.543405  0.278369  0.424518  0.844776  0.004719  0.121569  0.670749
# 1    0.891322  0.209202  0.185328  0.108377  0.219697  0.978624  0.811683
# 2    0.431704  0.940030  0.817649  0.336112  0.175410  0.372832  0.005689
# 3    0.598843  0.603805  0.105148  0.381943  0.036476  0.890412  0.980921
# 4    0.742480  0.630184  0.581842  0.020439  0.210027  0.544685  0.769115
# 5    0.975006  0.884853  0.359508  0.598859  0.354796  0.340190  0.178081
# 6    0.376252  0.592805  0.629942  0.142600  0.933841  0.946380  0.602297
# 7    0.276765  0.246536  0.173608  0.966610  0.957013  0.597974  0.731301
# 8    0.508699  0.088460  0.528035  0.992158  0.395036  0.335596  0.805451
# 9    0.540405  0.296794  0.110788  0.312640  0.456979  0.658940  0.254258
# 10   0.778289  0.779598  0.610328  0.309000  0.697735  0.859618  0.625324
# 11   0.023178  0.160745  0.923497  0.953550  0.210978  0.360525  0.549375
# ...

# %%
net.load_df(df)
net.cluster(enrichrgram=False)
net.widget()
# Out:
# Can not make widget because Network has no attribute widget_class
# Please instantiate Network with clustergrammer_widget using: Network(clustergrammer_widget)

# %%
Network(clustergrammer_widget)

# %%
net.widget()
# Out:
# Can not make widget because Network has no attribute widget_class
# Please instantiate Network with clustergrammer_widget using: Network(clustergrammer_widget)

# %%
#pip install jupyter_contrib_nbextensions

# %%
--py --sys-prefix widgetsnbextension
 --py --sys-prefix clustergrammer_widget
# Out:
#   File "<ipython-input-18-5c54944b9523>", line 1
#     --py --sys-prefix widgetsnbextension
#                                        ^
# SyntaxError: invalid syntax

# %%
net = Network(clustergrammer_widget)

# %%
net.load_file('Desktop/biojupie_expression.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-448a9b0c4e44> in <module>
# ----> 1 net.load_file('Desktop/biojupie_expression.txt')
#
# ~/anaconda3/lib/python3.7/site-packages/clustergrammer_widget/clustergrammer/__init__.py in load_file(self, filename)
#      45     Load TSV file.
#      46     '''
# ---> 47     load_data.load_file(self, filename)
#      48
#      49   def load_file_as_string(self, file_string, filename=''):
#
# ~/anaconda3/lib/python3.7/site-packages/clustergrammer_widget/clustergrammer/load_data.py in load_file(net, filename)
#      20   net.reset()
#      21
# ---> 22   f = open(filename, 'r')
#      23
#      24   file_string = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop/biojupie_expression.txt'

# %%
jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
#   File "<ipython-input-21-e3a674b8a334>", line 1
#     jupyter nbextension enable --py --sys-prefix widgetsnbextension
#                       ^
# SyntaxError: invalid syntax

# %%
pip install ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
#   File "<ipython-input-23-e3a674b8a334>", line 1
#     jupyter nbextension enable --py --sys-prefix widgetsnbextension
#                       ^
# SyntaxError: invalid syntax

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
net.load_df(df)

# %%
from clustergrammer2 import net
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv('Desktop/biojupie_expression.csv', index_col=0)

# %%
from ast import literal_eval as make_tuple
cols = df.columns.tolist()
new_cols = [make_tuple(x) for x in cols]
df.columns = new_cols
